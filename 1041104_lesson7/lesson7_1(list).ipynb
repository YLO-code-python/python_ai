# %%
city1 = '台北'
city2 = '台中'
city3 = '高雄'

print(city1)
print(city2)
print(city3)
# Out:
# 台北
# 台中
# 高雄

# %%
# []建立list
cities = ['台北','台中','高雄']  #[index 由0開始]；[0,1,2,3]
print(cities)
print(cities[0])
print(cities[1])
print(cities[2])
#print(cities[3])
# Out:
# ['台北', '台中', '高雄']
# 台北
# 台中
# 高雄

# %%
greetings = ["H","e","l","l","o"," ","w","o","r","l","d","i"]
greetings
# Out:
# ['H', 'e', 'l', 'l', 'o', ' ', 'w', 'o', 'r', 'l', 'd', 'i']

# %%
# 建立list的實體
# type 為反向查詢實體的屬性為何
greetings = list("Hello World!")
print(type(greetings)) # <class 'list'>
print(greetings)
print(greetings[0])
print(greetings[11])
# Out:
# <class 'list'>
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'l', 'd', '!']
# H
# !
